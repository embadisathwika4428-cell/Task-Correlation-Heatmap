# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create sample dataset
data = {
    'Math': [85, 78, 90, 66, 88, 76, 95, 89, 73, 84],
    'Science': [80, 75, 92, 65, 85, 74, 96, 87, 70, 82],
    'English': [78, 72, 88, 60, 84, 70, 90, 85, 68, 80]
}

df = pd.DataFrame(data)

# Correlation Matrix
corr_matrix = df.corr()

print(corr_matrix)

# Heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Student Scores")
plt.show()
# Out:
#              Math   Science   English
# Math     1.000000  0.980157  0.991703
# Science  0.980157  1.000000  0.986652
# English  0.991703  0.986652  1.000000
